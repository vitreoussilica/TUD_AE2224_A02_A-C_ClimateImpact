# %%
import xarray as x

data_ac_rr = x.open_dataset("/Users/gerbendrijfhout/Desktop/Project/project_data/f100___________20180101_0000_airtraf_ac_rr.nc")
data_ac = x.open_dataset("/Users/gerbendrijfhout/Desktop/Project/project_data/f100___________20180101_0000_airtraf_ac.nc")

# %%
data_ac
# Out:
# <xarray.Dataset>
# Dimensions:                      (time: 31, lon: 128, lat: 64,
#                                   AirTraf_routes_out: 100,
#                                   AirTraf_properties: 16,
#                                   AirTraf_waypoints_out: 101,
#                                   AirTraf_routes_fp: 100, tbnds: 2)
# Coordinates:
#   * time                         (time) datetime64[ns] 2018-01-01 ... 2018-01-31
#   * lon                          (lon) float32 0.0 2.812 5.625 ... 354.4 357.2
#   * lat                          (lat) float32 87.86 85.1 82.31 ... -85.1 -87.86
# Dimensions without coordinates: AirTraf_routes_out, AirTraf_properties,
#                                 AirTraf_waypoints_out, AirTraf_routes_fp, tbnds
# Data variables: (12/18)
#     YYYYMMDD                     (time) float64 ...
#     dt                           (time) float64 ...
#     nstep                        (time) float64 ...
# ...

# %%
departures_lat = data_ac.variables['routes_flightplan_D_lat']
departures_long = data_ac.variables['routes_flightplan_D_lon']
time = data_ac.variables['routes_out'].data[3,0,3,1]
print(time)

print(departures_lat.data[0,:])
print(departures_long.data[0,:])
# Out:
# 33.0214
# [41.2753 41.2753 52.3086 41.8003 40.4719 38.7813 69.6833 28.0445 48.7233
#  51.4706 41.8003 51.4706 37.9364 50.9014 36.6749 39.5517 51.4706 51.4706
#  41.2753 59.6519 28.0445 52.3086 36.6749 51.1481 40.4719 38.7813 39.5517
#  40.4719 40.4719 44.5711 60.3172 53.6304 40.4719 48.7233 37.9364 51.4706
#  38.7813 60.1939 51.4706 36.6749 43.6291 41.2971 52.5597 40.4675 48.3538
#  51.8747 28.4827 52.5597 27.9319 38.7813 51.4706 52.3086 50.0333 41.2753
#  60.3172 55.6179 52.3086 49.0128 40.4719 40.9951 59.6519 38.7813 41.2971
#  39.5517 28.4827 40.4719 41.2971 41.2971 41.8003 50.0333 36.8987 51.2895
#  43.6584 41.8003 48.7233 40.8986 36.6749 41.2753 36.8987 50.0333 40.4719
#  39.5517 51.1481 50.0333 51.4706 51.1481 51.2895 41.2753 48.7233 52.3086
#  48.3538 49.0128 40.4719 50.9014 50.8659 41.2481 49.0128 51.2895 40.4719
#  53.3537]
# [ 28.7519  28.7519   4.7639  12.2389  -3.5626  -9.1359  18.9189 -16.5725
#    2.3794  -0.4619  12.2389  -0.4619  23.9445   4.4844  -4.4991   2.7388
# ...

# %%
routes_out = data_ac.variables['routes_out']
routes_out
# Out:
# <xarray.Variable (time: 31, AirTraf_routes_out: 100, AirTraf_properties: 16,
#                   AirTraf_waypoints_out: 101)>
# [5009600 values with dtype=float32]
# Attributes:
#     cell_methods:  time: point

# %% [markdown]
# routes_out = data_ac.variables['routes_out']
#
# print(routes_out.data[0,:,0,-1])
# print(routes_out.data[0,:,1,-1])
